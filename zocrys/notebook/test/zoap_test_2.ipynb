# %%
from sys import path
path.insert(0, '/home/azadoks/git/glosim2/')
path.insert(0, '/home/azadoks/git/structureREST/zocrys/lib/')
from collections import OrderedDict
from pymatgen import MPRester
from libmatch.soap import get_Soaps
import numpy as np
import zoap
# Out:
# /home/azadoks/miniconda3/envs/python2/lib/python2.7/site-packages/pymatgen/__init__.py:87: UserWarning:
# Pymatgen will drop Py2k support from v2019.1.1. Pls consult the documentation
# at https://www.pymatgen.org for more details.
#   at https://www.pymatgen.org for more details.""")

# %%
material_ids = OrderedDict([
    ('diamond', 'mp-66'),  # C
    ('gaas', 'mp-2534'),  # GaAs
    ('rocksalt', 'mp-22862'),  # NaCl
    ('cubic_perovskite', 'mp-2998'),  # BaTiO3
    ('tetragonal_perovskite', 'mp-5986'),  # BaTiO3
    ('trigonal_perovskite', 'mp-5020'),  # BaTiO3
    ('orthorhombic_perovskite', 'mp-5777'),  # BaTiO3
    ('zincblende', 'mp-10695'),  # ZnS
    ('wurtzite', 'mp-10281'),  # ZnS
    ('fcc', 'mp-23'),  # Ni
    ('big_fcc', 'mp-76'),  # Sr
    ('bcc', 'mp-13'),  # Fe
    ('big_bcc', 'mp-70'),  # Rb
    ('hcp', 'mp-153'),  # Mg
    ('trigonal', 'mp-782'),  # Te2Pd
    ('tetragonal', 'mp-742'),  # Ti2Cu
    ('monoclinic', 'mp-684'),  # BaS2
    ('triclinic', 'mp-9122'),  # CaP3
    ('orthorhombic', 'mp-872')  # BaSn
])

# %%
with MPRester('0WqdPfXxloze6T9N') as mpr:
    # Get structures
    structures = OrderedDict([(name, mpr.get_structure_by_material_id(id)) for name, id in material_ids.iteritems()])
qps = OrderedDict([(name, zoap.structure2qp(structure,
                                            anonymize=True, scale=True,
                                            standardize=True, primitivize=True)
                   )
                   for name, structure in structures.iteritems()])

# %%
soaps = get_Soaps(qps.values(),
                  nocenters=None, chem_channels=False,
                  centerweight=1.0, gaussian_width=0.5,
                  cutoff=2.5, cutoff_transition_width=0.5,
                  nmax=16, lmax=14,
                  spkitMax=None, nprocess=8,
                  chemicalProjection=None, dispbar=False,
                  is_fast_average=False)
# Out:
# HBox(children=(IntProgress(value=0, description=u'SOAP vectors', max=19), HTML(value=u'')))
# [OrderedDict([('H0', array([1.91930415e-01, 7.61647604e-06, 1.12840569e-05, ...,
#         2.42512594e-10, 1.11042451e-07, 0.00000000e+00])), ('H1', array([1.91930415e-01, 7.61647604e-06, 1.12840569e-05, ...,
#         2.42512594e-10, 1.11042451e-07, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([8.72924682e-03, 3.75058470e-07, 7.86882255e-07, ...,
#         1.53802326e-04, 2.85863014e-01, 0.00000000e+00])), ('H1', array([8.72924682e-03, 3.75058470e-07, 7.86882255e-07, ...,
#         1.53802326e-04, 2.85863014e-01, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([1.89306035e-01, 6.45713847e-35, 1.80369183e-34, ...,
#         5.51506148e-44, 1.50576613e-10, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([4.03449104e-01, 2.74690875e-02, 9.29208534e-04, ...,
#         2.23222851e-05, 3.07876606e-02, 0.00000000e+00])), ('H3', array([3.19023058e-02, 1.06996755e-04, 3.57157681e-05, ...,
#         1.12061276e-04, 2.83150953e-01, 0.00000000e+00])), ('H4', array([2.00263735e-01, 7.63572126e-04, 3.45303293e-03, ...,
#         3.08719913e-10, 2.21357260e-07, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([8.72923839e-03, 3.75058108e-07, 7.86881496e-07, ...,
#         1.53802462e-04, 2.85863015e-01, 0.00000000e+00])), ('H1', array([8.72923839e-03, 3.75058108e-07, 7.86881496e-07, ...,
#         1.53802462e-04, 2.85863015e-01, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([2.19721152e-12, 2.15318365e-13, 1.42503576e-14, ...,
#         2.89252716e-05, 2.86121372e-01, 0.00000000e+00])), ('H1', array([3.20004950e-12, 1.56493376e-15, 7.14559582e-14, ...,
#         2.89252710e-05, 2.86121372e-01, 0.00000000e+00])), ('H2', array([1.62304536e-12, 3.72365648e-14, 2.70878655e-14, ...,
#         2.87934761e-05, 2.86102165e-01, 0.00000000e+00])), ('H3', array([2.22528919e-12, 8.08183331e-14, 3.06291954e-14, ...,
#         2.87633731e-05, 2.86116918e-01, 0.00000000e+00])), ('H4', array([2.79001070e-12, 9.94075617e-14, 4.35834619e-14, ...,
#         2.89252711e-05, 2.86121372e-01, 0.00000000e+00])), ('H5', array([2.95663515e-12, 6.58090464e-14, 5.37377126e-14, ...,
#         2.89252712e-05, 2.86121372e-01, 0.00000000e+00])), ('H6', array([1.75635637e-12, 9.70278288e-16, 3.59881902e-14, ...,
#         2.88222199e-05, 2.86102166e-01, 0.00000000e+00])), ('H7', array([1.75612673e-12, 1.74419730e-13, 9.50472350e-15, ...,
#         2.87979317e-05, 2.86116922e-01, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([1.70852089e-01, 3.06009202e-35, 3.18822662e-35, ...,
#         1.07817518e-43, 2.69575856e-11, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([1.70852089e-01, 3.75418102e-35, 2.01359668e-35, ...,
#         5.84772690e-44, 9.27018498e-11, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([1.50247765e-01, 2.32685325e-34, 2.24146660e-35, ...,
#         4.49552957e-43, 1.11173346e-11, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([1.50247765e-01, 3.76575128e-35, 1.03694210e-34, ...,
#         2.51327283e-43, 1.10327356e-11, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([1.85761815e-01, 1.44708164e-03, 7.75395460e-04, ...,
#         8.54918975e-10, 5.80383468e-07, 0.00000000e+00])), ('H1', array([1.85761815e-01, 1.44708164e-03, 7.75395460e-04, ...,
#         8.54918975e-10, 5.80383468e-07, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([1.95658907e-01, 8.18169824e-04, 2.11961867e-04, ...,
#         8.83580962e-10, 4.53995755e-07, 0.00000000e+00])), ('H1', array([2.04053428e-01, 2.93907466e-05, 7.57170684e-04, ...,
#         2.89104745e-08, 2.35354167e-05, 0.00000000e+00])), ('H2', array([1.89094074e-01, 1.08935363e-03, 9.82888667e-06, ...,
#         2.75786522e-08, 2.17390481e-05, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([3.22167542e-01, 4.58811520e-06, 1.11081993e-02, ...,
#         6.48623451e-05, 1.05333813e-01, 0.00000000e+00])), ('H1', array([9.69734676e-02, 3.89760018e-09, 3.23721049e-03, ...,
#         1.97449044e-05, 2.74756599e-01, 0.00000000e+00])), ('H2', array([1.93419520e-01, 2.46962997e-06, 6.69028354e-03, ...,
#         1.56636954e-04, 2.37150737e-01, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([2.29908370e-01, 1.86178960e-02, 5.43689142e-04, ...,
#         3.17958065e-05, 5.60490202e-02, 0.00000000e+00])), ('H1', array([3.26108397e-01, 2.85678694e-04, 5.53628694e-03, ...,
#         3.16087227e-05, 5.64749715e-02, 0.00000000e+00])), ('H2', array([3.26239399e-01, 2.85793454e-04, 5.53851092e-03, ...,
#         3.10074744e-05, 5.59129226e-02, 0.00000000e+00])), ('H3', array([2.29996781e-01, 1.86250555e-02, 5.43898218e-04, ...,
#         3.11713166e-05, 5.55066457e-02, 0.00000000e+00])), ('H4', array([2.94143145e-01, 6.96128457e-03, 3.88901636e-03, ...,
#         5.32065278e-05, 9.86134960e-02, 0.00000000e+00])), ('H5', array([2.94143145e-01, 6.96128457e-03, 3.88901636e-03, ...,
#         5.32065238e-05, 9.86134961e-02, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([5.23993945e-03, 1.53334282e-04, 3.13724795e-05, ...,
#         1.36446645e-04, 2.86047292e-01, 0.00000000e+00])), ('H1', array([5.23993945e-03, 1.53334282e-04, 3.13724795e-05, ...,
#         1.36446645e-04, 2.86047292e-01, 0.00000000e+00])), ('H2', array([4.30286189e-03, 2.01657239e-04, 2.46311666e-05, ...,
#         1.37267214e-04, 2.86037657e-01, 0.00000000e+00])), ('H3', array([4.30286189e-03, 2.01657239e-04, 2.46311666e-05, ...,
#         1.37267214e-04, 2.86037657e-01, 0.00000000e+00])), ('H4', array([2.29094854e-01, 1.00622266e-02, 1.04902467e-03, ...,
#         7.69889857e-08, 9.06206716e-05, 0.00000000e+00])), ('H5', array([2.29094854e-01, 1.00622266e-02, 1.04902467e-03, ...,
#         7.69889857e-08, 9.06206715e-05, 0.00000000e+00])), ('H6', array([3.02977798e-01, 5.07284767e-03, 2.88647219e-04, ...,
#         1.06700599e-06, 1.70280668e-03, 0.00000000e+00])), ('H7', array([3.02977798e-01, 5.07284767e-03, 2.88647219e-04, ...,
#         1.06700599e-06, 1.70280668e-03, 0.00000000e+00]))]),
#  OrderedDict([('H0', array([1.81315432e-01, 1.50816923e-04, 1.29023587e-03, ...,
#         6.81766723e-05, 1.37351959e-01, 0.00000000e+00])), ('H1', array([1.81315432e-01, 1.50816923e-04, 1.29023587e-03, ...,
#         6.81766723e-05, 1.37351959e-01, 0.00000000e+00])), ('H2', array([1.64960211e-01, 2.09951829e-03, 1.78742597e-04, ...,
#         6.83441281e-05, 1.40569399e-01, 0.00000000e+00])), ('H3', array([1.64960211e-01, 2.09951829e-03, 1.78742597e-04, ...,
#         6.83441281e-05, 1.40569399e-01, 0.00000000e+00]))])]
